# %%
dbutils.fs.mkdirs("dbfs:/databricks/init_scripts/")
 
dbutils.fs.put("/databricks/init_scripts/init.sh","""
#!/bin/bash
sudo wget -O /databricks/jars/rapids-4-spark_2.12-0.5.jar https://repo1.maven.org/maven2/com/nvidia/rapids-4-spark_2.12/0.5/rapids-4-spark_2.12-0.5.jar
sudo wget -O /databricks/jars/cudf-0.19-cuda10-1.jar https://repo1.maven.org/maven2/ai/rapids/cudf/0.19/cudf-0.19-cuda10-1.jar""", True)

# %%
# %sh
cd ../../dbfs/databricks/init_scripts
pwd
ls -ltr
cat init.sh
